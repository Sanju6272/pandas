# %% [markdown]
# # Terror Attack City
# Problem Statement :
# The Most Dangerous city in Jammu and Kashmir and the terrorist group which is most active in that city?
# Print count of number of attacks in that city as integer value.
# Note:Ignoring the Unknown Terrorist Group.Here Dangerous related with the number of terrorist attacks.
# Output Format :
# City NumberOfAttack Group

# %%
import csv
import pandas as pd

# %%
iris=pd.read_csv('terrorismData.csv',encoding='utf8')

# %%
df=iris.copy()

# %%
df=df[df['State']=='Jammu and Kashmir']

# %%
df
# Out:
#         Year  Month  Day Country              State      Region  \
# 21744   1984      4   17   India  Jammu and Kashmir  South Asia
# 22108   1984      5   20   India  Jammu and Kashmir  South Asia
# 29677   1986     12   11   India  Jammu and Kashmir  South Asia
# 33202   1988      1   21   India  Jammu and Kashmir  South Asia
# 33372   1988      2    7   India  Jammu and Kashmir  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181222  2017     12   11   India  Jammu and Kashmir  South Asia
# 181396  2017     12   18   India  Jammu and Kashmir  South Asia
# 181414  2017     12   19   India  Jammu and Kashmir  South Asia
# 181476  2017     12   22   India  Jammu and Kashmir  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
#
#                       City   Latitude  Longitude         AttackType  Killed  \
# 21744                Bhela  33.315527  74.622476      Assassination     2.0
# ...

# %%
cities=df['City']

# %%
cities
# Out:
# 21744                  Bhela
# 22108                  Jammu
# 29677                 Madora
# 33202                   Mand
# 33372              Kherawali
#                  ...
# 181222      Kralcheck Keller
# 181396    Baramulla district
# 181414      Pulwama district
# 181476              Srinagar
# 181672             Lethapora
# Name: City, Length: 2454, dtype: object

# %%
city=cities.value_counts()

# %%
city
# Out:
# Srinagar     657
# Sopore       102
# Unknown       86
# Anantnag      76
# Jammu         57
#             ...
# Bragam         1
# Narsu          1
# Lasjan         1
# Goriwan        1
# Lethapora      1
# Name: City, Length: 633, dtype: int64

# %%
print(city.index[0])
print(city.values[0])
# Out:
# Srinagar
# 657

# %%
df=df[df['City']==city.index[0]]

# %%
group=df['Group']

# %%
group
# Out:
# 35266      Sikh Extremists
# 35267      Sikh Extremists
# 36073              Unknown
# 36074     Muslim Militants
# 36078     Muslim Militants
#                 ...
# 179570             Unknown
# 179684             Unknown
# 180599             Unknown
# 180822             Unknown
# 181476             Unknown
# Name: Group, Length: 657, dtype: object

# %%
group.value_counts().index[0]
# Out:
# 'Unknown'

# %%
group.value_counts().index[1]
# Out:
# 'Muslim Separatists'

# %% [markdown]
# # Terror Government
# Problem Statement :
# There was formation of new government in India on 26 May 2014. So current government's span is from 26th May 2014 to current. Find out two things from this period-
# 1. Total number of attacks done in this period in India. Find this count as integer.
# 2. Which Terrorist group was most active in this period in India. Most active means, group which has done maximum number of attacks.
# 3.Ignore the Unknown group.
# Output Format :
# TotalAttacks MostActiveTerroristGroup

# %%
import csv
import pandas as pd

# %%
original_data=pd.read_csv('terrorismData.csv')
df=original_data.copy()
df=df[df['Country']=='India']

# %%
df
# Out:
#         Year  Month  Day Country              State      Region  \
# 1186    1972      2   22   India              Delhi  South Asia
# 2764    1975      1    2   India              Bihar  South Asia
# 3857    1976      5   26   India              Delhi  South Asia
# 5327    1977      9   28   India        Maharashtra  South Asia
# 7337    1979      1   13   India              Assam  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 1186        New Delhi  28.585836  77.153336                       Hijacking
# ...

# %%
ind=df[(df.Year>2014) | ((df.Year==2014) & (df.Month>=6)) | ((df.Year==2014) & (df.Month==5) & (df.Day>=26))]
ind
# Out:
#         Year  Month  Day Country              State      Region  \
# 132468  2014      5   26   India     Andhra Pradesh  South Asia
# 132496  2014      5   26   India        West Bengal  South Asia
# 132502  2014      5   26   India        West Bengal  South Asia
# 132526  2014      5   27   India  Jammu and Kashmir  South Asia
# 132555  2014      5   27   India             Odisha  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 132468    Bandlapalli  14.714739  77.810281               Bombing/Explosion
# ...

# %%
ind.Year.count()
# Out:
# 3336

# %%
attacks=ind[ind['Group']!='Unknown']
attacks
# Out:
#         Year  Month  Day Country              State      Region  \
# 132559  2014      5   27   India          Meghalaya  South Asia
# 132600  2014      5   28   India       Chhattisgarh  South Asia
# 132604  2014      5   28   India             Odisha  South Asia
# 132605  2014      5   28   India             Odisha  South Asia
# 132673  2014      5   29   India        Maharashtra  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181606  2017     12   28   India              Bihar  South Asia
# 181612  2017     12   28   India            Manipur  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
#
#                        City   Latitude  Longitude  \
# 132559       Daji Badimagre  25.396733  90.475623
# 132600     Bijapur district  18.797297  80.813178
# ...

# %%
attacks.Group.value_counts().index[0]
# Out:
# 'Maoists'

# %%
attacks.Group.value_counts().values[0]
# Out:
# 854

# %% [markdown]
# # Terror Government
# Problem Statement :
# There was formation of new government in India on 26 May 2014. So current government's span is from 26th May 2014 to current. Find out two things from this period-
# 1. Total number of attacks done in this period in India. Find this count as integer.
# 2. Which Terrorist group was most active in this period in India. Most active means, group which has done maximum number of attacks.
# 3.Ignore the Unknown group.
# Output Format :
# TotalAttacks MostActiveTerroristGroup

# %%
import csv
import pandas as pd
import numpy as np

# %%
iris=pd.read_csv('terrorismData.csv',encoding='utf8')
df=iris.copy()
df=df[df['Country']=='India']

# %%
ind=df[(df['Year']>2014) | ((df['Year']==2014) & (df['Month']>5)) | ((df['Year']==2014) & (df['Month']==5) & (df['Day']>=26))]
ind
# Out:
#         Year  Month  Day Country              State      Region  \
# 132468  2014      5   26   India     Andhra Pradesh  South Asia
# 132496  2014      5   26   India        West Bengal  South Asia
# 132502  2014      5   26   India        West Bengal  South Asia
# 132526  2014      5   27   India  Jammu and Kashmir  South Asia
# 132555  2014      5   27   India             Odisha  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 132468    Bandlapalli  14.714739  77.810281               Bombing/Explosion
# ...

# %%
groups=ind['Group']
len(groups)
# Out:
# 3336

# %%
groups.value_counts()
# Out:
# Unknown                                                        1279
# Maoists                                                         854
# Communist Party of India - Maoist (CPI-Maoist)                  327
# Hizbul Mujahideen (HM)                                           78
# Lashkar-e-Taiba (LeT)                                            69
#                                                                ...
# Tribal Revolutionary Army (TRA)                                   1
# National Socialist Council of Nagaland-Unification (NSCN-U)       1
# Revolutionary Communist Centre (RCC)                              1
# Tiwa Liberation Army                                              1
# Ansar Ghazwat-ul-Hind                                             1
# Name: Group, Length: 117, dtype: int64

# %%
groups.value_counts().index[1]
# Out:
# 'Maoists'

# %% [markdown]
# # Terror Frequency
# Problem Statement :
# Find the frequency of the Casualty in Red Corridor states and in Jammu and Kashmir ?Here Frequency is (Total Casualty/Total Number of a year)
# Print frequency as integer value.
# Note:Red Corridor state includes Jharkhand, Odisha, Andhra Pradesh, and Chhattisgarh. Here Casualty=Killed +Wounded.Don't fill the nan value present in Killed and Wounded feature.
# Output Format :
# Frequency1 Frequency2

# %%
import csv
import pandas as pd

# %%
import numpy as np

# %%
original_data=pd.read_csv('terrorismData.csv')
df=original_data.copy()

# %%
years=len(set(df['Year']))
df=df[df['Country']=='India']
df
# Out:
#         Year  Month  Day Country              State      Region  \
# 1186    1972      2   22   India              Delhi  South Asia
# 2764    1975      1    2   India              Bihar  South Asia
# 3857    1976      5   26   India              Delhi  South Asia
# 5327    1977      9   28   India        Maharashtra  South Asia
# 7337    1979      1   13   India              Assam  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 1186        New Delhi  28.585836  77.153336                       Hijacking
# ...

# %%
years
# Out:
# 47

# %%
df['Casualty']=df['Killed'] + df['Wounded']

# %%
df
# Out:
#         Year  Month  Day Country              State      Region  \
# 1186    1972      2   22   India              Delhi  South Asia
# 2764    1975      1    2   India              Bihar  South Asia
# 3857    1976      5   26   India              Delhi  South Asia
# 5327    1977      9   28   India        Maharashtra  South Asia
# 7337    1979      1   13   India              Assam  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 1186        New Delhi  28.585836  77.153336                       Hijacking
# ...

# %%
Jammu_state=df[df['State']=='Jammu and Kashmir']

# %%
Jammu_state
# Out:
#         Year  Month  Day Country              State      Region  \
# 21744   1984      4   17   India  Jammu and Kashmir  South Asia
# 22108   1984      5   20   India  Jammu and Kashmir  South Asia
# 29677   1986     12   11   India  Jammu and Kashmir  South Asia
# 33202   1988      1   21   India  Jammu and Kashmir  South Asia
# 33372   1988      2    7   India  Jammu and Kashmir  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181222  2017     12   11   India  Jammu and Kashmir  South Asia
# 181396  2017     12   18   India  Jammu and Kashmir  South Asia
# 181414  2017     12   19   India  Jammu and Kashmir  South Asia
# 181476  2017     12   22   India  Jammu and Kashmir  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
#
#                       City   Latitude  Longitude         AttackType  Killed  \
# 21744                Bhela  33.315527  74.622476      Assassination     2.0
# ...

# %%
red_state=df[(df['State']=='Jharkhand') | (df['State']=='Odisha') | (df['State']=='Andhra Pradesh') | (df['State']=='Chhattisgarh')]
red_state
# Out:
#         Year  Month  Day Country           State      Region          City  \
# 9053    1979      8    8   India  Andhra Pradesh  South Asia        Amapur
# 9148    1979      8   26   India       Jharkhand  South Asia    Jamshedpur
# 9166    1979      8   29   India       Jharkhand  South Asia    Jamshedpur
# 18417   1983      3   30   India    Chhattisgarh  South Asia  Baloda Bazar
# 27651   1986      3   26   India  Andhra Pradesh  South Asia     Anantapur
# ...      ...    ...  ...     ...             ...         ...           ...
# 181586  2017     12   27   India    Chhattisgarh  South Asia      Basaguda
# 181587  2017     12   27   India    Chhattisgarh  South Asia      Basaguda
# 181615  2017     12   28   India       Jharkhand  South Asia    Pandrasali
# 181661  2017     12   28   India  Andhra Pradesh  South Asia     Talacheru
# 181665  2017     12   30   India    Chhattisgarh  South Asia      Toylanka
#
# ...

# %%
red_casualty=int(np.sum(red_state['Casualty']))

# %%
red_casualty
# Out:
# 5448

# %%
Jammu_casualty=int(np.sum(Jammu_state['Casualty']))

# %%
Jammu_casualty
# Out:
# 12268

# %%
print(red_casualty//years,Jammu_casualty//years)
# Out:
# 115 261

# %% [markdown]
# # Terror DeadliestAttack
# Problem Statement :
# Most Deadliest attack in a history of HumanKind?
# Print count of Killed people as integer value.
# Note: Here Deadliest attack means, in which the most number of people killed.
# Output Format :
# NumberOfPeopleKilled Country TerroristGroup

# %%
import csv
import pandas as pd
import numpy as np

# %%
iris=pd.read_csv('terrorismData.csv',encoding='utf8')
df=iris.copy()

# %%
maxkilled=max(df.Killed)
maxkilled
# Out:
# 1570.0

# %%
groups=df[df['Killed']==maxkilled]
groups
# Out:
#         Year  Month  Day Country    State                      Region    City  \
# 133518  2014      6   12    Iraq  Saladin  Middle East & North Africa  Tikrit
#
#          Latitude  Longitude                   AttackType  Killed  Wounded  \
# 133518  34.621521  43.668377  Hostage Taking (Kidnapping)  1570.0      NaN
#
#           Target                                            Summary  \
# 133518  Soldiers  06/12/2014: Assailants abducted approximately ...
#
#                                               Group Target_type Weapon_type
# 133518  Islamic State of Iraq and the Levant (ISIL)    Military    Firearms

# %%
groups['Group'].values[0]
# Out:
# 'Islamic State of Iraq and the Levant (ISIL)'

# %%
country=df[df['Killed']==maxkilled]
country
# Out:
#         Year  Month  Day Country    State                      Region    City  \
# 133518  2014      6   12    Iraq  Saladin  Middle East & North Africa  Tikrit
#
#          Latitude  Longitude                   AttackType  Killed  Wounded  \
# 133518  34.621521  43.668377  Hostage Taking (Kidnapping)  1570.0      NaN
#
#           Target                                            Summary  \
# 133518  Soldiers  06/12/2014: Assailants abducted approximately ...
#
#                                               Group Target_type Weapon_type
# 133518  Islamic State of Iraq and the Levant (ISIL)    Military    Firearms

# %%
country['Country'].values[0]
# Out:
# 'Iraq'

# %%
import csv
import numpy as np
import pandas as pd

# %%
iris=pd.read_csv('terrorismData.csv',encoding='utf8')
df=iris.copy()

# %%
countries=df['Country'].value_counts()
countries
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# International              1
# Wallis and Futuna          1
# South Vietnam              1
# Andorra                    1
# Antigua and Barbuda        1
# Name: Country, Length: 205, dtype: int64

# %%
countries.index[0]
# Out:
# 'Iraq'

# %%
countries.values[0]
# Out:
# 24636

# %%
years=df[df['Country']==countries.index[0]]
years
# Out:
#         Year  Month  Day Country    State                      Region  \
# 2854    1975      3    1    Iraq  Nineveh  Middle East & North Africa
# 4385    1976     12   15    Iraq  Baghdad  Middle East & North Africa
# 4393    1976     12   18    Iraq  Unknown  Middle East & North Africa
# 4402    1976     12   24    Iraq  Baghdad  Middle East & North Africa
# 8688    1979      6   15    Iraq    Basra  Middle East & North Africa
# ...      ...    ...  ...     ...      ...                         ...
# 181669  2017     12   30    Iraq   Kirkuk  Middle East & North Africa
# 181670  2017     12   31    Iraq   Diyala  Middle East & North Africa
# 181671  2017     12   31    Iraq  Saladin  Middle East & North Africa
# 181674  2017     12   31    Iraq  Nineveh  Middle East & North Africa
# 181679  2017     12   31    Iraq   Diyala  Middle East & North Africa
#
#                 City   Latitude  Longitude                   AttackType  \
# ...

# %%
year=years['Year'].value_counts()
year
# Out:
# 2014    3933
# 2016    3360
# 2013    2852
# 2015    2751
# 2017    2466
# 2012    1437
# 2011    1308
# 2010    1179
# 2009    1137
# 2008    1106
# 2007    1047
# 2006     838
# 2005     617
# 2004     323
# 2003     102
# 1992      35
# 1997      21
# 1994      18
# 1995      17
# 1999      12
# 1996      12
# 2000      10
# 1998       7
# 1980       6
# 2002       6
# 1982       5
# 1988       4
# 1989       4
# 1983       3
# 1981       3
# 2001       3
# 1987       3
# 1991       3
# 1976       3
# 1984       2
# 1979       2
# 1975       1
# Name: Year, dtype: int64

# %%
year.index[0]
# Out:
# 2014

# %%
year.values[0]
# Out:
# 3933
